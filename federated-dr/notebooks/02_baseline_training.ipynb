# %% [markdown]
# # Baseline Training
#
# This notebook demonstrates centralized (baseline) training.

# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))

# Run baseline experiment
# %run ../experiments/baseline.py
