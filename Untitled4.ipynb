# %% [markdown]
# <a href="https://colab.research.google.com/github/lubaina1904/diabetic-retinopathy-ml/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
    function ClickConnect(){
        console.log("Keeping session alive");
        document.querySelector("colab-connect-button")?.shadowRoot.querySelector("#connect").click()
    }
    setInterval(ClickConnect, 60000)
'''))

# %%
# !git clone https://github.com/lubaina1904/diabetic-retinopathy-ml
# %cd diabetic-retinopathy-ml
# Out:
# fatal: destination path 'diabetic-retinopathy-ml' already exists and is not an empty directory.
# /content/diabetic-retinopathy-ml

# %%
# !pip install -r requirements.txt

# %%
# !mkdir -p data/aptos/train_images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf data/aptos              # remove existing folder if any
# !mkdir -p data
# !ln -s "/content/drive/MyDrive/federated-dr/data/aptos" "data/aptos"

# %%
# !ls data/aptos
# Out:
# test.csv  test_images  train.csv  train_images

# %%
# !python experiments/baseline.py
# Out:
# ...
# BASELINE EXPERIMENT - CENTRALIZED TRAINING
# ...
#
# Configuration:
#   csv_file: /content/diabetic-retinopathy-ml/data/aptos/train.csv
#   img_dir: /content/diabetic-retinopathy-ml/data/aptos/train_images
#   model_name: efficientnet_b0
#   num_classes: 5
#   pretrained: True
#   batch_size: 32
#   num_epochs: 20
#   learning_rate: 0.001
#   val_split: 0.2
#   num_workers: 2
#   device: cpu
#   save_dir: /content/diabetic-retinopathy-ml/results/models/baseline
#
# Device: cpu
#
# ...
# Loading Dataset...
# ...
# Filtering CSV to only include available images...
# Loaded 2173 images (filtered from 3662 in CSV)
# Class distribution: Counter({0: 1328, 2: 448, 1: 180, 4: 133, 3: 84})
# Train size: 1739
# Val size: 434
# Train batches: 55
# Val batches: 14
#
# ...
# Creating Model...
# ...
# model.safetensors: 100% 21.4M/21.4M [00:00<00:00, 23.7MB/s]
# Created efficientnet_b0 model
# Feature dimension: 1280
# Output classes: 5
# Total parameters: 4,013,953
# Trainable parameters: 4,013,953
#
# ...
# Training Model...
# ...

# %%
# !python experiments/fedavg.py
# Out:
# 2025-11-08 13:26:20.249149: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762608380.284831   27721 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762608380.296033   27721 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762608380.323062   27721 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
