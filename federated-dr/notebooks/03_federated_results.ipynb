# %% [markdown]
# # Federated Learning Results Analysis
#
# This notebook compares baseline vs federated learning results.

# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))

import json
import matplotlib.pyplot as plt
import pandas as pd

# Load results
with open('../results/baseline_results.json', 'r') as f:
    baseline = json.load(f)

with open('../results/fedavg_results.json', 'r') as f:
    fedavg = json.load(f)

print("Baseline vs Federated Learning Comparison")
print(f"Baseline Accuracy: {baseline['evaluation']['accuracy']:.2f}%")
print(f"FedAvg Accuracy: {fedavg['best_round']['accuracy']:.2f}%")
